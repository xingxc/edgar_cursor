# %%
import requests
import edgar_functions
from bs4 import BeautifulSoup
from edgar_functions import statement_keys_map

headers = {"User-agent": "email@email.com"}
ticker_list = ["appl", "pypl", ""]
ticker = "aapl"

# %% [markdown]
# #### Return the accesssion number
#
# Accession number parameters.
# - ticker
# - 10-K or 10-Q
# - return accession number only

# %%
acc = edgar_functions.get_filter_filing(
    ticker, headers=headers, ten_k=True, accession_number_only=True
)
display(acc)

acc_num = acc.iloc[0].replace("-", "")  # accession number
# Out:
# reportDate
# 2022-12-31    0000950170-23-001409
# 2021-12-31    0000950170-22-000796
# 2020-12-31    0001564590-21-004599
# 2019-12-31    0001564590-20-004475
# 2018-12-31    0001564590-19-003165
# 2017-12-31    0001564590-18-002956
# 2016-12-31    0001564590-17-003118
# 2015-12-31    0001564590-16-013195
# Name: accessionNumber, dtype: object

# %% [markdown]
# #### Return the beautiful soup statements
#
# - balance sheet
# - income statement
# - cash flow statement

# %%
statement_balance_sheet = "balance_sheet"
statement_income_statement = "income_statement"
statement_cash_flow_statement = "cash_flow_statement"

soup_balance_sheet = edgar_functions.get_statement_soup(
    ticker, acc_num, statement_balance_sheet, headers, statement_keys_map
)

soup_income_statement = edgar_functions.get_statement_soup(
    ticker, acc_num, statement_income_statement, headers, statement_keys_map
)

soup_cash_flow_statement = edgar_functions.get_statement_soup(
    ticker, acc_num, statement_cash_flow_statement, headers, statement_keys_map
)

# The logged links of the quries are stored in:
edgar_functions.links_logged
# Out:
# {'pypl-balance_sheet-R3.htm-000163391723000033': 'https://www.sec.gov/Archives/edgar/data/0001633917/000163391723000033/R3.htm',
#  'pypl-income_statement-R5.htm-000163391723000033': 'https://www.sec.gov/Archives/edgar/data/0001633917/000163391723000033/R5.htm',
#  'pypl-cash_flow_statement-R8.htm-000163391723000033': 'https://www.sec.gov/Archives/edgar/data/0001633917/000163391723000033/R8.htm',
#  'aapl-balance_sheet-R5.htm-000032019323000106': 'https://www.sec.gov/Archives/edgar/data/0000320193/000032019323000106/R5.htm',
#  'aapl-income_statement-R3.htm-000032019323000106': 'https://www.sec.gov/Archives/edgar/data/0000320193/000032019323000106/R3.htm',
#  'aapl-cash_flow_statement-R8.htm-000032019323000106': 'https://www.sec.gov/Archives/edgar/data/0000320193/000032019323000106/R8.htm',
#  'tsla-balance_sheet-R2.htm-000095017023001409': 'https://www.sec.gov/Archives/edgar/data/0001318605/000095017023001409/R2.htm',
#  'tsla-income_statement-R4.htm-000095017023001409': 'https://www.sec.gov/Archives/edgar/data/0001318605/000095017023001409/R4.htm',
#  'tsla-cash_flow_statement-R9.htm-000095017023001409': 'https://www.sec.gov/Archives/edgar/data/0001318605/000095017023001409/R9.htm'}

# %% [markdown]
# #### Column, Date-Time, and, Values of the Statements
# Return the column-names, Date-Time, and, Values of each statement
# - balance sheet
# - income statement
# - cash flow statement

# %%
(
    columns_balance_sheet,
    values_set_balance_sheet,
    date_time_index_balance_sheet,
) = edgar_functions.extract_columns_values_and_dates_from_statement(
    soup=soup_balance_sheet
)

(
    columns_income_statement,
    values_set_income_statement,
    date_time_index_income_statement,
) = edgar_functions.extract_columns_values_and_dates_from_statement(
    soup=soup_income_statement
)

(
    columns_cash_flow_statement,
    values_set_cash_flow_statement,
    date_time_index_cash_flow_statement,
) = edgar_functions.extract_columns_values_and_dates_from_statement(
    soup=soup_cash_flow_statement
)

# %% [markdown]
# #### Construct the DataFrame from Column, Date-Time, and, Values of the Statements
# - balance sheet
# - income statement
# - cash flow statement

# %%
df_balance_sheet = edgar_functions.create_dataframe_of_statement_values_columns_dates(
    values_set_balance_sheet,
    columns_balance_sheet,
    date_time_index_balance_sheet,
)

df_income = edgar_functions.create_dataframe_of_statement_values_columns_dates(
    values_set_income_statement,
    columns_income_statement,
    date_time_index_income_statement,
)

df_cash_flow = edgar_functions.create_dataframe_of_statement_values_columns_dates(
    values_set_cash_flow_statement,
    columns_cash_flow_statement,
    date_time_index_cash_flow_statement,
)

display(df_balance_sheet.transpose()/1000)
display(df_income.transpose()/1000)
display(df_cash_flow.transpose()/1000)
# Out:
#                                                     2022-12-31  2021-12-31
# us-gaap_AssetsCurrentAbstract                              NaN         NaN
# us-gaap_CashAndCashEquivalentsAtCarryingValue          16253.0     17576.0
# us-gaap_ShortTermInvestments                            5932.0       131.0
# us-gaap_AccountsReceivableNetCurrent                    2952.0      1913.0
# us-gaap_InventoryNet                                   12839.0      5757.0
# us-gaap_PrepaidExpenseAndOtherAssetsCurrent             2941.0      1723.0
# us-gaap_AssetsCurrent                                  40917.0     27100.0
# us-gaap_PropertyPlantAndEquipmentNet                   23548.0     18884.0
# us-gaap_OperatingLeaseRightOfUseAsset                   2563.0      2016.0
# tsla_DigitalAssetsNetNonCurrent                          184.0      1260.0
# us-gaap_IntangibleAssetsNetExcludingGoodwill             215.0       257.0
# us-gaap_Goodwill                                         194.0       200.0
# us-gaap_OtherAssetsNoncurrent                           4193.0      2138.0
# us-gaap_Assets                                         82338.0     62131.0
# us-gaap_LiabilitiesCurrentAbstract                         NaN         NaN
# us-gaap_AccountsPayableCurrent                         15255.0     10025.0
# tsla_AccruedAndOtherCurrentLiabilities                  7142.0      5719.0
# us-gaap_ContractWithCustomerLiabilityCurrent            1747.0      1447.0
# tsla_CustomerDepositsLiabilitiesCurrent                 1063.0       925.0
# tsla_LongTermDebtAndFinanceLeasesCurrent                1502.0      1589.0
# us-gaap_LiabilitiesCurrent                             26709.0     19705.0
# tsla_LongTermDebtAndFinanceLeasesNoncurrent             1597.0      5245.0
# us-gaap_ContractWithCustomerLiabilityNoncurrent         2804.0      2052.0
# us-gaap_OtherLiabilitiesNoncurrent                      5330.0      3546.0
# us-gaap_Liabilities                                    36440.0     30548.0
# us-gaap_CommitmentsAndContingencies                        NaN         NaN
# us-gaap_RedeemableNoncontrollingInterestEquityC...       409.0       568.0
# us-gaap_StockholdersEquityAbstract                         NaN         NaN
# us-gaap_PreferredStockValue                                0.0         0.0
# us-gaap_CommonStockValue                                   3.0         3.0
# us-gaap_AdditionalPaidInCapitalCommonStock             32177.0     29803.0
# us-gaap_AccumulatedOtherComprehensiveIncomeLoss...      -361.0        54.0
# us-gaap_RetainedEarningsAccumulatedDeficit             12885.0       329.0
# us-gaap_StockholdersEquity                             44704.0     30189.0
# us-gaap_MinorityInterest                                 785.0       826.0
# us-gaap_LiabilitiesAndStockholdersEquity               82338.0     62131.0
# us-gaap_PropertyPlantAndEquipmentByTypeAxis=tsl...         NaN         NaN
# us-gaap_AssetsCurrentAbstract                              NaN         NaN
# us-gaap_DeferredCostsLeasingNetNoncurrent               5035.0      4511.0
# us-gaap_PropertyPlantAndEquipmentByTypeAxis=tsl...         NaN         NaN
# us-gaap_AssetsCurrentAbstract                              NaN         NaN
# tsla_LeasedAssetsNet                                    5489.0      5765.0
#                                                     2022-12-31  2021-12-31  \
# us-gaap_RevenuesAbstract                                   NaN         NaN
# us-gaap_Revenues                                      81462.00    53823.00
# us-gaap_CostOfRevenueAbstract                              NaN         NaN
# us-gaap_CostOfRevenue                                 60609.00    40217.00
# us-gaap_GrossProfit                                   20853.00    13606.00
# us-gaap_OperatingExpensesAbstract                          NaN         NaN
# us-gaap_ResearchAndDevelopmentExpense                  3075.00     2593.00
# us-gaap_SellingGeneralAndAdministrativeExpense         3946.00     4517.00
# tsla_RestructuringAndOtherExpenses                      176.00      -27.00
# us-gaap_OperatingExpenses                              7197.00     7083.00
# us-gaap_OperatingIncomeLoss                           13656.00     6523.00
# us-gaap_InvestmentIncomeInterest                        297.00       56.00
# us-gaap_InterestExpense                                -191.00     -371.00
# us-gaap_OtherNonoperatingIncomeExpense                  -43.00      135.00
# us-gaap_IncomeLossFromContinuingOperationsBefor...    13719.00     6343.00
# us-gaap_IncomeTaxExpenseBenefit                        1132.00      699.00
# us-gaap_ProfitLoss                                    12587.00     5644.00
# us-gaap_NetIncomeLossAttributableToNoncontrolli...       31.00      125.00
# us-gaap_NetIncomeLoss                                 12556.00     5519.00
# us-gaap_EarningsPerShareAbstract                           NaN         NaN
# us-gaap_EarningsPerShareBasic                             4.02        1.87
# us-gaap_EarningsPerShareDiluted                           3.62        1.63
# us-gaap_WeightedAverageNumberOfSharesOutstandin...         NaN         NaN
# us-gaap_WeightedAverageNumberOfSharesOutstandin...     3130.00     2959.00
# us-gaap_WeightedAverageNumberOfDilutedSharesOut...     3475.00     3386.00
# srt_ProductOrServiceAxis=tsla_AutomotiveRevenue...         NaN         NaN
# us-gaap_RevenuesAbstract                                   NaN         NaN
# tsla_AutomotiveSalesRevenue                           67210.00    44125.00
# tsla_AutomotiveRegulatoryCredits                       1776.00     1465.00
# tsla_AutomotiveLeasing                                 2476.00     1642.00
# tsla_AutomotiveRevenues                               71462.00    47232.00
# us-gaap_CostOfRevenueAbstract                              NaN         NaN
# tsla_AutomotiveSales                                  49599.00    32415.00
# us-gaap_DirectCostsOfLeasedAndRentedPropertyOrE...     1509.00      978.00
# tsla_AutomotiveCostOfRevenues                         51108.00    33393.00
# srt_ProductOrServiceAxis=tsla_EnergyGenerationA...         NaN         NaN
# us-gaap_RevenuesAbstract                                   NaN         NaN
# us-gaap_RevenueFromContractWithCustomerExcludin...     3909.00     2789.00
# us-gaap_CostOfRevenueAbstract                              NaN         NaN
# us-gaap_CostOfGoodsAndServicesSold                     3621.00     2918.00
# srt_ProductOrServiceAxis=tsla_ServicesAndOtherM...         NaN         NaN
# us-gaap_RevenuesAbstract                                   NaN         NaN
# us-gaap_RevenueFromContractWithCustomerExcludin...     6091.00     3802.00
# us-gaap_CostOfRevenueAbstract                              NaN         NaN
# us-gaap_CostOfGoodsAndServicesSold                     5880.00     3906.00
#
#                                                     2020-12-31
# us-gaap_RevenuesAbstract                                   NaN
# us-gaap_Revenues                                      31536.00
# us-gaap_CostOfRevenueAbstract                              NaN
# us-gaap_CostOfRevenue                                 24906.00
# us-gaap_GrossProfit                                    6630.00
# us-gaap_OperatingExpensesAbstract                          NaN
# us-gaap_ResearchAndDevelopmentExpense                  1491.00
# us-gaap_SellingGeneralAndAdministrativeExpense         3145.00
# tsla_RestructuringAndOtherExpenses                        0.00
# us-gaap_OperatingExpenses                              4636.00
# us-gaap_OperatingIncomeLoss                            1994.00
# us-gaap_InvestmentIncomeInterest                         30.00
# us-gaap_InterestExpense                                -748.00
# us-gaap_OtherNonoperatingIncomeExpense                 -122.00
# us-gaap_IncomeLossFromContinuingOperationsBefor...     1154.00
# us-gaap_IncomeTaxExpenseBenefit                         292.00
# us-gaap_ProfitLoss                                      862.00
# us-gaap_NetIncomeLossAttributableToNoncontrolli...      141.00
# us-gaap_NetIncomeLoss                                   721.00
# us-gaap_EarningsPerShareAbstract                           NaN
# us-gaap_EarningsPerShareBasic                             0.25
# us-gaap_EarningsPerShareDiluted                           0.21
# us-gaap_WeightedAverageNumberOfSharesOutstandin...         NaN
# us-gaap_WeightedAverageNumberOfSharesOutstandin...     2798.00
# us-gaap_WeightedAverageNumberOfDilutedSharesOut...     3249.00
# srt_ProductOrServiceAxis=tsla_AutomotiveRevenue...         NaN
# us-gaap_RevenuesAbstract                                   NaN
# tsla_AutomotiveSalesRevenue                           24604.00
# tsla_AutomotiveRegulatoryCredits                       1580.00
# tsla_AutomotiveLeasing                                 1052.00
# tsla_AutomotiveRevenues                               27236.00
# us-gaap_CostOfRevenueAbstract                              NaN
# tsla_AutomotiveSales                                  19696.00
# us-gaap_DirectCostsOfLeasedAndRentedPropertyOrE...      563.00
# tsla_AutomotiveCostOfRevenues                         20259.00
# srt_ProductOrServiceAxis=tsla_EnergyGenerationA...         NaN
# us-gaap_RevenuesAbstract                                   NaN
# us-gaap_RevenueFromContractWithCustomerExcludin...     1994.00
# us-gaap_CostOfRevenueAbstract                              NaN
# us-gaap_CostOfGoodsAndServicesSold                     1976.00
# srt_ProductOrServiceAxis=tsla_ServicesAndOtherM...         NaN
# us-gaap_RevenuesAbstract                                   NaN
# us-gaap_RevenueFromContractWithCustomerExcludin...     2306.00
# us-gaap_CostOfRevenueAbstract                              NaN
# us-gaap_CostOfGoodsAndServicesSold                     2671.00
#                                                     2022-12-31  2021-12-31  \
# us-gaap_NetCashProvidedByUsedInOperatingActivit...         NaN         NaN
# us-gaap_ProfitLoss                                     12587.0      5644.0
# us-gaap_AdjustmentsToReconcileNetIncomeLossToCa...         NaN         NaN
# tsla_DepreciationAmortizationAndImpairment              3747.0      2911.0
# us-gaap_ShareBasedCompensation                          1560.0      2121.0
# us-gaap_InventoryWriteDown                               177.0       140.0
# us-gaap_ForeignCurrencyTransactionGainLossUnrea...        81.0       -55.0
# tsla_NoncashInterestIncomeExpenseAndOtherOperat...       340.0       245.0
# tsla_GainLossOnDigitalAssets                             140.0       -27.0
# us-gaap_IncreaseDecreaseInOperatingCapitalAbstract         NaN         NaN
# us-gaap_IncreaseDecreaseInAccountsReceivable           -1124.0      -130.0
# us-gaap_IncreaseDecreaseInInventories                  -6465.0     -1709.0
# tsla_IncreaseDecreaseInOperatingLeaseVehicles          -1570.0     -2114.0
# us-gaap_IncreaseDecreaseInPrepaidDeferredExpens...     -1417.0      -271.0
# us-gaap_IncreaseDecreaseInOtherNoncurrentAssets        -2551.0     -1291.0
# us-gaap_IncreaseDecreaseInAccountsPayableAndAcc...      6029.0      4578.0
# us-gaap_IncreaseDecreaseInContractWithCustomerL...      1131.0       793.0
# tsla_IncreaseDecreaseInContractWithCustomerLiab...       155.0       186.0
# us-gaap_IncreaseDecreaseInOtherNoncurrentLiabil...      1904.0       476.0
# us-gaap_NetCashProvidedByUsedInOperatingActivities     14724.0     11497.0
# us-gaap_NetCashProvidedByUsedInInvestingActivit...         NaN         NaN
# us-gaap_PaymentsToAcquirePropertyPlantAndEquipment     -7158.0     -6482.0
# tsla_PaymentsForSolarEnergySystemsNetOfSales              -5.0       -32.0
# tsla_PurchaseOfDigitalAssets                               0.0     -1500.0
# tsla_ProceedsFromSalesOfDigitalAssets                    936.0       272.0
# tsla_PaymentsToAcquireOtherIndefiniteLivedIntan...        -9.0         0.0
# us-gaap_PaymentsToAcquireInvestments                   -5835.0      -132.0
# us-gaap_ProceedsFromSaleMaturityAndCollectionsO...        22.0         0.0
# tsla_GovernmentGrantReceipt                               76.0         6.0
# us-gaap_PaymentsToAcquireBusinessesNetOfCashAcq...         0.0         0.0
# us-gaap_NetCashProvidedByUsedInInvestingActivities    -11973.0     -7868.0
# us-gaap_NetCashProvidedByUsedInFinancingActivit...         NaN         NaN
# us-gaap_ProceedsFromIssuanceOfCommonStock                  0.0         0.0
# us-gaap_ProceedsFromIssuanceOfDebt                         0.0      8883.0
# tsla_RepaymentsOfConvertibleAndOtherDebt               -3364.0    -14167.0
# us-gaap_ProceedsFromRepaymentsOfSecuredDebt                0.0        -9.0
# us-gaap_ProceedsFromIssuanceOfSharesUnderIncent...       541.0       707.0
# us-gaap_FinanceLeasePrincipalPayments                   -502.0      -439.0
# us-gaap_PaymentsOfDebtIssuanceCosts                        0.0        -9.0
# us-gaap_ProceedsFromMinorityShareholders                   0.0         2.0
# us-gaap_PaymentsToMinorityShareholders                  -157.0      -161.0
# tsla_PaymentsForBuyOutsOfNoncontrollingInterest...       -45.0       -10.0
# us-gaap_NetCashProvidedByUsedInFinancingActivities     -3527.0     -5203.0
# us-gaap_EffectOfExchangeRateOnCashCashEquivalen...      -444.0      -183.0
# us-gaap_CashCashEquivalentsRestrictedCashAndRes...     -1220.0     -1757.0
# us-gaap_CashCashEquivalentsRestrictedCashAndRes...     18144.0     19901.0
# us-gaap_CashCashEquivalentsRestrictedCashAndRes...     16924.0     18144.0
# us-gaap_NoncashInvestingAndFinancingItemsAbstract          NaN         NaN
# us-gaap_NoncashOrPartNoncashAcquisitionValueOfA...      2148.0      2251.0
# us-gaap_SupplementalCashFlowInformationAbstract            NaN         NaN
# us-gaap_InterestPaidNet                                  152.0       266.0
# us-gaap_IncomeTaxesPaid                                 1203.0       561.0
#
#                                                     2020-12-31
# us-gaap_NetCashProvidedByUsedInOperatingActivit...         NaN
# us-gaap_ProfitLoss                                       862.0
# us-gaap_AdjustmentsToReconcileNetIncomeLossToCa...         NaN
# tsla_DepreciationAmortizationAndImpairment              2322.0
# us-gaap_ShareBasedCompensation                          1734.0
# us-gaap_InventoryWriteDown                               202.0
# us-gaap_ForeignCurrencyTransactionGainLossUnrea...       114.0
# tsla_NoncashInterestIncomeExpenseAndOtherOperat...       525.0
# tsla_GainLossOnDigitalAssets                               0.0
# us-gaap_IncreaseDecreaseInOperatingCapitalAbstract         NaN
# us-gaap_IncreaseDecreaseInAccountsReceivable            -652.0
# us-gaap_IncreaseDecreaseInInventories                   -422.0
# tsla_IncreaseDecreaseInOperatingLeaseVehicles          -1072.0
# us-gaap_IncreaseDecreaseInPrepaidDeferredExpens...      -251.0
# us-gaap_IncreaseDecreaseInOtherNoncurrentAssets         -344.0
# us-gaap_IncreaseDecreaseInAccountsPayableAndAcc...      2102.0
# us-gaap_IncreaseDecreaseInContractWithCustomerL...       321.0
# tsla_IncreaseDecreaseInContractWithCustomerLiab...         7.0
# us-gaap_IncreaseDecreaseInOtherNoncurrentLiabil...       495.0
# us-gaap_NetCashProvidedByUsedInOperatingActivities      5943.0
# us-gaap_NetCashProvidedByUsedInInvestingActivit...         NaN
# us-gaap_PaymentsToAcquirePropertyPlantAndEquipment     -3157.0
# tsla_PaymentsForSolarEnergySystemsNetOfSales             -75.0
# tsla_PurchaseOfDigitalAssets                               0.0
# tsla_ProceedsFromSalesOfDigitalAssets                      0.0
# tsla_PaymentsToAcquireOtherIndefiniteLivedIntan...       -10.0
# us-gaap_PaymentsToAcquireInvestments                       0.0
# us-gaap_ProceedsFromSaleMaturityAndCollectionsO...         0.0
# tsla_GovernmentGrantReceipt                              123.0
# us-gaap_PaymentsToAcquireBusinessesNetOfCashAcq...       -13.0
# us-gaap_NetCashProvidedByUsedInInvestingActivities     -3132.0
# us-gaap_NetCashProvidedByUsedInFinancingActivit...         NaN
# us-gaap_ProceedsFromIssuanceOfCommonStock              12269.0
# us-gaap_ProceedsFromIssuanceOfDebt                      9713.0
# tsla_RepaymentsOfConvertibleAndOtherDebt              -11623.0
# us-gaap_ProceedsFromRepaymentsOfSecuredDebt             -240.0
# us-gaap_ProceedsFromIssuanceOfSharesUnderIncent...       417.0
# us-gaap_FinanceLeasePrincipalPayments                   -338.0
# us-gaap_PaymentsOfDebtIssuanceCosts                       -6.0
# us-gaap_ProceedsFromMinorityShareholders                  24.0
# us-gaap_PaymentsToMinorityShareholders                  -208.0
# tsla_PaymentsForBuyOutsOfNoncontrollingInterest...       -35.0
# us-gaap_NetCashProvidedByUsedInFinancingActivities      9973.0
# us-gaap_EffectOfExchangeRateOnCashCashEquivalen...       334.0
# us-gaap_CashCashEquivalentsRestrictedCashAndRes...     13118.0
# us-gaap_CashCashEquivalentsRestrictedCashAndRes...      6783.0
# us-gaap_CashCashEquivalentsRestrictedCashAndRes...     19901.0
# us-gaap_NoncashInvestingAndFinancingItemsAbstract          NaN
# us-gaap_NoncashOrPartNoncashAcquisitionValueOfA...      1088.0
# us-gaap_SupplementalCashFlowInformationAbstract            NaN
# us-gaap_InterestPaidNet                                  444.0
# us-gaap_IncomeTaxesPaid                                  115.0

# %% [markdown]
# #### Process the entire statement
#
# Process entire statement

# %%
df_balance_sheet0 = edgar_functions.process_one_statement(
    ticker, acc_num, statement_balance_sheet, headers
)

df_income0 = edgar_functions.process_one_statement(
    ticker, acc_num, statement_income_statement, headers
)

df_cash_flow0 = edgar_functions.process_one_statement(
    ticker, acc_num, statement_cash_flow_statement, headers
)

display(df_balance_sheet0/1000)
display(df_income0/1000)
display(df_cash_flow0/1000)
# Out:
#                                                     2022-12-31  2021-12-31
# us-gaap_AssetsCurrentAbstract                              NaN         NaN
# us-gaap_CashAndCashEquivalentsAtCarryingValue          16253.0     17576.0
# us-gaap_ShortTermInvestments                            5932.0       131.0
# us-gaap_AccountsReceivableNetCurrent                    2952.0      1913.0
# us-gaap_InventoryNet                                   12839.0      5757.0
# us-gaap_PrepaidExpenseAndOtherAssetsCurrent             2941.0      1723.0
# us-gaap_AssetsCurrent                                  40917.0     27100.0
# us-gaap_PropertyPlantAndEquipmentNet                   23548.0     18884.0
# us-gaap_OperatingLeaseRightOfUseAsset                   2563.0      2016.0
# tsla_DigitalAssetsNetNonCurrent                          184.0      1260.0
# us-gaap_IntangibleAssetsNetExcludingGoodwill             215.0       257.0
# us-gaap_Goodwill                                         194.0       200.0
# us-gaap_OtherAssetsNoncurrent                           4193.0      2138.0
# us-gaap_Assets                                         82338.0     62131.0
# us-gaap_AccountsPayableCurrent                         15255.0     10025.0
# tsla_AccruedAndOtherCurrentLiabilities                  7142.0      5719.0
# us-gaap_ContractWithCustomerLiabilityCurrent            1747.0      1447.0
# tsla_CustomerDepositsLiabilitiesCurrent                 1063.0       925.0
# tsla_LongTermDebtAndFinanceLeasesCurrent                1502.0      1589.0
# us-gaap_LiabilitiesCurrent                             26709.0     19705.0
# tsla_LongTermDebtAndFinanceLeasesNoncurrent             1597.0      5245.0
# us-gaap_ContractWithCustomerLiabilityNoncurrent         2804.0      2052.0
# us-gaap_OtherLiabilitiesNoncurrent                      5330.0      3546.0
# us-gaap_Liabilities                                    36440.0     30548.0
# us-gaap_RedeemableNoncontrollingInterestEquityC...       409.0       568.0
# us-gaap_PreferredStockValue                                0.0         0.0
# us-gaap_CommonStockValue                                   3.0         3.0
# us-gaap_AdditionalPaidInCapitalCommonStock             32177.0     29803.0
# us-gaap_AccumulatedOtherComprehensiveIncomeLoss...      -361.0        54.0
# us-gaap_RetainedEarningsAccumulatedDeficit             12885.0       329.0
# us-gaap_StockholdersEquity                             44704.0     30189.0
# us-gaap_MinorityInterest                                 785.0       826.0
# us-gaap_DeferredCostsLeasingNetNoncurrent               5035.0      4511.0
# tsla_LeasedAssetsNet                                    5489.0      5765.0
#                                                     2022-12-31  2021-12-31  \
# us-gaap_RevenuesAbstract                                   NaN         NaN
# us-gaap_Revenues                                      81462.00    53823.00
# us-gaap_CostOfRevenue                                 60609.00    40217.00
# us-gaap_GrossProfit                                   20853.00    13606.00
# us-gaap_ResearchAndDevelopmentExpense                  3075.00     2593.00
# us-gaap_SellingGeneralAndAdministrativeExpense         3946.00     4517.00
# tsla_RestructuringAndOtherExpenses                      176.00      -27.00
# us-gaap_OperatingExpenses                              7197.00     7083.00
# us-gaap_OperatingIncomeLoss                           13656.00     6523.00
# us-gaap_InvestmentIncomeInterest                        297.00       56.00
# us-gaap_InterestExpense                                -191.00     -371.00
# us-gaap_OtherNonoperatingIncomeExpense                  -43.00      135.00
# us-gaap_IncomeLossFromContinuingOperationsBefor...    13719.00     6343.00
# us-gaap_IncomeTaxExpenseBenefit                        1132.00      699.00
# us-gaap_ProfitLoss                                    12587.00     5644.00
# us-gaap_NetIncomeLossAttributableToNoncontrolli...       31.00      125.00
# us-gaap_NetIncomeLoss                                 12556.00     5519.00
# us-gaap_EarningsPerShareBasic                             4.02        1.87
# us-gaap_EarningsPerShareDiluted                           3.62        1.63
# us-gaap_WeightedAverageNumberOfSharesOutstandin...     3130.00     2959.00
# us-gaap_WeightedAverageNumberOfDilutedSharesOut...     3475.00     3386.00
# tsla_AutomotiveSalesRevenue                           67210.00    44125.00
# tsla_AutomotiveRegulatoryCredits                       1776.00     1465.00
# tsla_AutomotiveLeasing                                 2476.00     1642.00
# tsla_AutomotiveRevenues                               71462.00    47232.00
# tsla_AutomotiveSales                                  49599.00    32415.00
# us-gaap_DirectCostsOfLeasedAndRentedPropertyOrE...     1509.00      978.00
# tsla_AutomotiveCostOfRevenues                         51108.00    33393.00
# us-gaap_RevenueFromContractWithCustomerExcludin...     3909.00     2789.00
# us-gaap_CostOfGoodsAndServicesSold                     3621.00     2918.00
# us-gaap_RevenueFromContractWithCustomerExcludin...     6091.00     3802.00
# us-gaap_CostOfGoodsAndServicesSold                     5880.00     3906.00
#
#                                                     2020-12-31
# us-gaap_RevenuesAbstract                                   NaN
# us-gaap_Revenues                                      31536.00
# us-gaap_CostOfRevenue                                 24906.00
# us-gaap_GrossProfit                                    6630.00
# us-gaap_ResearchAndDevelopmentExpense                  1491.00
# us-gaap_SellingGeneralAndAdministrativeExpense         3145.00
# tsla_RestructuringAndOtherExpenses                        0.00
# us-gaap_OperatingExpenses                              4636.00
# us-gaap_OperatingIncomeLoss                            1994.00
# us-gaap_InvestmentIncomeInterest                         30.00
# us-gaap_InterestExpense                                -748.00
# us-gaap_OtherNonoperatingIncomeExpense                 -122.00
# us-gaap_IncomeLossFromContinuingOperationsBefor...     1154.00
# us-gaap_IncomeTaxExpenseBenefit                         292.00
# us-gaap_ProfitLoss                                      862.00
# us-gaap_NetIncomeLossAttributableToNoncontrolli...      141.00
# us-gaap_NetIncomeLoss                                   721.00
# us-gaap_EarningsPerShareBasic                             0.25
# us-gaap_EarningsPerShareDiluted                           0.21
# us-gaap_WeightedAverageNumberOfSharesOutstandin...     2798.00
# us-gaap_WeightedAverageNumberOfDilutedSharesOut...     3249.00
# tsla_AutomotiveSalesRevenue                           24604.00
# tsla_AutomotiveRegulatoryCredits                       1580.00
# tsla_AutomotiveLeasing                                 1052.00
# tsla_AutomotiveRevenues                               27236.00
# tsla_AutomotiveSales                                  19696.00
# us-gaap_DirectCostsOfLeasedAndRentedPropertyOrE...      563.00
# tsla_AutomotiveCostOfRevenues                         20259.00
# us-gaap_RevenueFromContractWithCustomerExcludin...     1994.00
# us-gaap_CostOfGoodsAndServicesSold                     1976.00
# us-gaap_RevenueFromContractWithCustomerExcludin...     2306.00
# us-gaap_CostOfGoodsAndServicesSold                     2671.00
#                                                     2022-12-31  2021-12-31  \
# us-gaap_NetCashProvidedByUsedInOperatingActivit...         NaN         NaN
# us-gaap_ProfitLoss                                     12587.0      5644.0
# tsla_DepreciationAmortizationAndImpairment              3747.0      2911.0
# us-gaap_ShareBasedCompensation                          1560.0      2121.0
# us-gaap_InventoryWriteDown                               177.0       140.0
# us-gaap_ForeignCurrencyTransactionGainLossUnrea...        81.0       -55.0
# tsla_NoncashInterestIncomeExpenseAndOtherOperat...       340.0       245.0
# tsla_GainLossOnDigitalAssets                             140.0       -27.0
# us-gaap_IncreaseDecreaseInAccountsReceivable           -1124.0      -130.0
# us-gaap_IncreaseDecreaseInInventories                  -6465.0     -1709.0
# tsla_IncreaseDecreaseInOperatingLeaseVehicles          -1570.0     -2114.0
# us-gaap_IncreaseDecreaseInPrepaidDeferredExpens...     -1417.0      -271.0
# us-gaap_IncreaseDecreaseInOtherNoncurrentAssets        -2551.0     -1291.0
# us-gaap_IncreaseDecreaseInAccountsPayableAndAcc...      6029.0      4578.0
# us-gaap_IncreaseDecreaseInContractWithCustomerL...      1131.0       793.0
# tsla_IncreaseDecreaseInContractWithCustomerLiab...       155.0       186.0
# us-gaap_IncreaseDecreaseInOtherNoncurrentLiabil...      1904.0       476.0
# us-gaap_NetCashProvidedByUsedInOperatingActivities     14724.0     11497.0
# us-gaap_PaymentsToAcquirePropertyPlantAndEquipment     -7158.0     -6482.0
# tsla_PaymentsForSolarEnergySystemsNetOfSales              -5.0       -32.0
# tsla_PurchaseOfDigitalAssets                               0.0     -1500.0
# tsla_ProceedsFromSalesOfDigitalAssets                    936.0       272.0
# tsla_PaymentsToAcquireOtherIndefiniteLivedIntan...        -9.0         0.0
# us-gaap_PaymentsToAcquireInvestments                   -5835.0      -132.0
# us-gaap_ProceedsFromSaleMaturityAndCollectionsO...        22.0         0.0
# tsla_GovernmentGrantReceipt                               76.0         6.0
# us-gaap_PaymentsToAcquireBusinessesNetOfCashAcq...         0.0         0.0
# us-gaap_NetCashProvidedByUsedInInvestingActivities    -11973.0     -7868.0
# us-gaap_ProceedsFromIssuanceOfCommonStock                  0.0         0.0
# us-gaap_ProceedsFromIssuanceOfDebt                         0.0      8883.0
# tsla_RepaymentsOfConvertibleAndOtherDebt               -3364.0    -14167.0
# us-gaap_ProceedsFromRepaymentsOfSecuredDebt                0.0        -9.0
# us-gaap_ProceedsFromIssuanceOfSharesUnderIncent...       541.0       707.0
# us-gaap_FinanceLeasePrincipalPayments                   -502.0      -439.0
# us-gaap_PaymentsOfDebtIssuanceCosts                        0.0        -9.0
# us-gaap_ProceedsFromMinorityShareholders                   0.0         2.0
# us-gaap_PaymentsToMinorityShareholders                  -157.0      -161.0
# tsla_PaymentsForBuyOutsOfNoncontrollingInterest...       -45.0       -10.0
# us-gaap_NetCashProvidedByUsedInFinancingActivities     -3527.0     -5203.0
# us-gaap_EffectOfExchangeRateOnCashCashEquivalen...      -444.0      -183.0
# us-gaap_CashCashEquivalentsRestrictedCashAndRes...     -1220.0     -1757.0
# us-gaap_CashCashEquivalentsRestrictedCashAndRes...     18144.0     19901.0
# us-gaap_CashCashEquivalentsRestrictedCashAndRes...     16924.0     18144.0
# us-gaap_NoncashOrPartNoncashAcquisitionValueOfA...      2148.0      2251.0
# us-gaap_InterestPaidNet                                  152.0       266.0
# us-gaap_IncomeTaxesPaid                                 1203.0       561.0
#
#                                                     2020-12-31
# us-gaap_NetCashProvidedByUsedInOperatingActivit...         NaN
# us-gaap_ProfitLoss                                       862.0
# tsla_DepreciationAmortizationAndImpairment              2322.0
# us-gaap_ShareBasedCompensation                          1734.0
# us-gaap_InventoryWriteDown                               202.0
# us-gaap_ForeignCurrencyTransactionGainLossUnrea...       114.0
# tsla_NoncashInterestIncomeExpenseAndOtherOperat...       525.0
# tsla_GainLossOnDigitalAssets                               0.0
# us-gaap_IncreaseDecreaseInAccountsReceivable            -652.0
# us-gaap_IncreaseDecreaseInInventories                   -422.0
# tsla_IncreaseDecreaseInOperatingLeaseVehicles          -1072.0
# us-gaap_IncreaseDecreaseInPrepaidDeferredExpens...      -251.0
# us-gaap_IncreaseDecreaseInOtherNoncurrentAssets         -344.0
# us-gaap_IncreaseDecreaseInAccountsPayableAndAcc...      2102.0
# us-gaap_IncreaseDecreaseInContractWithCustomerL...       321.0
# tsla_IncreaseDecreaseInContractWithCustomerLiab...         7.0
# us-gaap_IncreaseDecreaseInOtherNoncurrentLiabil...       495.0
# us-gaap_NetCashProvidedByUsedInOperatingActivities      5943.0
# us-gaap_PaymentsToAcquirePropertyPlantAndEquipment     -3157.0
# tsla_PaymentsForSolarEnergySystemsNetOfSales             -75.0
# tsla_PurchaseOfDigitalAssets                               0.0
# tsla_ProceedsFromSalesOfDigitalAssets                      0.0
# tsla_PaymentsToAcquireOtherIndefiniteLivedIntan...       -10.0
# us-gaap_PaymentsToAcquireInvestments                       0.0
# us-gaap_ProceedsFromSaleMaturityAndCollectionsO...         0.0
# tsla_GovernmentGrantReceipt                              123.0
# us-gaap_PaymentsToAcquireBusinessesNetOfCashAcq...       -13.0
# us-gaap_NetCashProvidedByUsedInInvestingActivities     -3132.0
# us-gaap_ProceedsFromIssuanceOfCommonStock              12269.0
# us-gaap_ProceedsFromIssuanceOfDebt                      9713.0
# tsla_RepaymentsOfConvertibleAndOtherDebt              -11623.0
# us-gaap_ProceedsFromRepaymentsOfSecuredDebt             -240.0
# us-gaap_ProceedsFromIssuanceOfSharesUnderIncent...       417.0
# us-gaap_FinanceLeasePrincipalPayments                   -338.0
# us-gaap_PaymentsOfDebtIssuanceCosts                       -6.0
# us-gaap_ProceedsFromMinorityShareholders                  24.0
# us-gaap_PaymentsToMinorityShareholders                  -208.0
# tsla_PaymentsForBuyOutsOfNoncontrollingInterest...       -35.0
# us-gaap_NetCashProvidedByUsedInFinancingActivities      9973.0
# us-gaap_EffectOfExchangeRateOnCashCashEquivalen...       334.0
# us-gaap_CashCashEquivalentsRestrictedCashAndRes...     13118.0
# us-gaap_CashCashEquivalentsRestrictedCashAndRes...      6783.0
# us-gaap_CashCashEquivalentsRestrictedCashAndRes...     19901.0
# us-gaap_NoncashOrPartNoncashAcquisitionValueOfA...      1088.0
# us-gaap_InterestPaidNet                                  444.0
# us-gaap_IncomeTaxesPaid                                  115.0
